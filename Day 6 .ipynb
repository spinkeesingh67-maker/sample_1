# %%
import matplotlib.pyplot as plt
students = ["Amit","Rahul","Priya","Neha"]
marks = [75,82,91,68]
plt.plot(students, marks)
plt.show()

# %%
students = ["Amit","Rahul","Priya","Neha"] 
marks = [75,82,91,68]
plt.bar(students, marks)
plt.show()

# %%
subjects = ["Math","Science","English"] 
marks = [40,35,25]
plt.pie(marks, labels=subjects) 
plt.show()

# %%
import matplotlib.pyplot as plt
students = ["Amit","Rahul","Priya","Neha"] 
marks = [75,82,91,68]
plt.plot(students, marks) 
plt.title("Student Marks")
plt.xlabel("Students")
plt.ylabel("Marks")
plt.show()

# %%
months = [1,2,3,4,5]
sales1 = [10,20,25,35,40]
sales2 = [15,18,30,32,45]
plt.plot(months, sales1)
plt.plot(months, sales2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.array([
    [90,80,70],
    [60,75,85],
    [95,88,92],
    [70,65,78],
])

plt.imshow(data)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

temerature = np.array([
    [30,32,31],
    [35,36,34],
    [28,29,30],
    [40,39,41],
])

cities = ["Delhi","Mumbai","Shimla","Jaipur"]
days = ["Mon","Tue","Wed"]

plt.imshow(
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt
students = ["Amit","Gaurav","Riya","Geeta"]
marks = [34,87,95,45]
plt.plot(students,marks)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
y = [10,20,30,40,50]

plt.plot(x,y)

plt.show()

# %%
x = [2,5,8,10]
y = [1,4,7,9]
plt.plot(x,y)
plt.show()

# %%
x = [1,2,3,4,5,6]
y = [1,4,9,16,25,36]
plt.plot(x,y)
plt.show()

# %%
x = [1,2,3,4,5,6]
y = [5,20,10,35,5,10]

plt.plot(x,y)

plt.show()

# %%
students = ["Amit","Rahul","Parul","Neha"]
marks = [75,83,90,62]

plt.plot(students,marks)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


angles = np.linspace(0, 2 * np.pi, 6)

star_angles = [angles[0], angles[2], angles[4], angles[1], angles[3], angles[0]]

r = [1] * 6  


plt.figure(figsize=(5, 5))
plt.subplot(projection="polar")
plt.plot(star_angles, r, color="gold", linewidth=3)
plt.fill(star_angles, r, color="yellow", alpha=0.5) 
plt.axis("off")  
plt.title("Star Shape", fontsize=14)
plt.show()
